# %%
import import_ipynb
import basic as b
# Out:
# importing Jupyter notebook from basic.ipynb

# %% [markdown]
# <font face="微软雅黑" size=3 color=#A52A2A >
#     下面例子用的是 N0550398 如果用自己的文件 <br/>
#     file 格式为str; <br/>
#     doc=b.nlp(file)

# %%
# %store -r file
# %store -r doc

# %% [markdown]
# <font face="微软雅黑" size=5 color=#00000 >
# <table><tr><td bgcolor=orange>
#     tip1: %store var 储存变量               %store -r var 读取储存的变量<br/>
#     可以跨文件使用
#     </td></tr></table>

# %% [markdown]
# <font face="微软雅黑" size=3 color=#A52A2A >
#     先看原始的标签 已有的常用的类别： <br/>
#     person   <br/>
#     gpe  地理位置   <br/>
#     event   <br/>
#     date  <br/>
#     money   <br/>
#     norp 民族、宗教、政治团体   <br/>
#     org  公司、机构   <br/>
#     law  提到的文档 比如 charter xx   <br/>
#     完整文档 https://spacy.io/api/annotation/#named-entities

# %%
b.displacy.render(doc, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">[DU1]</br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Resolution
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  adopted by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the General Assembly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  on
# ...

# %% [markdown]
# <font face="微软雅黑" size=3 color=#A52A2A >
#     找到错误的地方，比如 <br/>
# <font face="微软雅黑" size=2 color=#000000 >
#     Decides to apportion among Member States the amount of 24 CARDINAL , 669 CARDINAL , 100 dollars MONEY for the period from 16 October 2006 DATE to 30 CARDINAL June 2007 DATE at a monthly DATE rate of 2 CARDINAL , 902 CARDINAL , 247 dollars MONEY <br/>
# <font face="微软雅黑" size=3 color=#A52A2A >
#     注意:<br/>
#     1. 重新定位的时候不要包含前后的空格 <br/>
#     2. 标记一句话的时候要把所有类别，无论正确的错误的，都要标出来 <br/>

# %% [markdown]
# <font face="微软雅黑" size=5 color=#00000 >
# <table><tr><td bgcolor=orange>
# tip2: 下面字符串第一行末尾 \ 是写不下换行符,不影响字符定位
#     </td></tr></table>

# %%
s="Decides to apportion among Member States the amount of 24,669,100 dollars for the period from \
16 October 2006 to 30 June 2007 at a monthly rate of 2,902,247 dollars"
print(s[55:73])
print(s[94:110])
print(s[113:125])
print(s[147:164])
# Out:
# 24,669,100 dollars
# 16 October 2006
# 30 June 2007
# 2,902,247 dollars

# %% [markdown]
# <font face="微软雅黑" size=3 color=#A52A2A >
#     如果有需要新加的标签，比如reso，就加到“labels”变量里，后面训练的函数会用到它 <br/>
#     labels 的格式是list，list中的标签与默认的类别用法一样<br/>
#     这里reso只是例子，实际resolution可以加到默认的law分类里

# %%
 labels=['RESO']

# %%
s2="the latest of which was resolution 1666 (2006) of 31 March 2006"
print(s2[24:46])
print(s2[50:63])
# Out:
# resolution 1666 (2006)
# 31 March 2006

# %%
s3="Recalling also Security Council resolution 858 (1993) of 24 August 1993 , \
by which the Council established the United Nations Observer Mission in Georgia"
print(s3[32:53])
print(s3[57:71])
print(s3[107:142])
print(s3[146:153])
# Out:
# resolution 858 (1993)
# 24 August 1993
# the United Nations Observer Mission
# Georgia

# %% [markdown]
# <font face="微软雅黑" size=3 color=#A52A2A >
#     手动标记的固定格式如下

# %%
train_data=[(s,{'entities': [(55, 73, 'MONEY'),(94,110,'DATE'),(113,125,'DATE'),(147,164,'MONEY')]}),
             (s2,{'entities':[(24,46,'RESO'),(50,63,'DATE')]}),
              (s3,{'entities':[(32,53,'RESO'),(57,71,'DATE'),(107,142,'ORG'),(146,153,'GPE')]})
           ]

# %% [markdown]
# <font face="微软雅黑" size=3 color=#A52A2A >
#     合并训练数据

# %%
### NER need training,train_data manually marked
b.TRAIN_DATA=b.TRAIN_DATA+train_data

# %% [markdown]
# <font face="微软雅黑" size=6 color=000000 >
#     训练模型main()的四个参数<br/>
# <font face="微软雅黑" size=3 color=#A52A2A >
#     1. 要训练的模型: "en_core_web_sm" 是spacy默认的； 如果train_data 足够也可以不用，说明从头开始训练<br/>
#     2. 模型输出路径: 可以在basic中 main 的参数里添加自己的默认路径<br/>
#     3. 迭代次数: 根据输出的loss还有没有下降的趋势调整，loss至少在10以内<br/>
#     4. labels: 格式是list，只写自己新加的label; 默认"None" 为没有新添加的

# %% [markdown]
# <font face="微软雅黑" size=5 color=#00000 >
# <table><tr><td bgcolor=orange>
# tip3: 一般来说，如果新加了自己需要的标签，迭代次数要600以上，没有新加，100以内
#     </td></tr></table>

# %%
# %%time
nlp_new=b.main("en_core_web_sm",r'D:\UN',labels=labels,n_iter=150) 
# %store nlp_new
# Out:
# Loaded model 'en_core_web_sm'
# Losses {'ner': 41.06627455088001}
# Losses {'ner': 44.374493354168614}
# Losses {'ner': 42.18089757513707}
# Losses {'ner': 37.08163991143951}
# Losses {'ner': 21.904125112664683}
# Losses {'ner': 9.03297656591673}
# Losses {'ner': 28.25278161816275}
# Losses {'ner': 17.002899410755568}
# Losses {'ner': 15.715019284091136}
# Losses {'ner': 7.32988768780927}
# Losses {'ner': 9.548669346670989}
# Losses {'ner': 6.259769236654124}
# Losses {'ner': 5.403493279925986}
# Losses {'ner': 4.300264375029161}
# Losses {'ner': 7.189799625518029}
# Losses {'ner': 3.7856615564813283}
# Losses {'ner': 2.4586869131256615}
# Losses {'ner': 3.388558471815778}
# Losses {'ner': 0.9254090451788411}
# Losses {'ner': 2.9190598077781447}
# Losses {'ner': 6.702306360982991}
# Losses {'ner': 2.712635815314939}
# Losses {'ner': 3.596230984746105}
# Losses {'ner': 0.004243947762187366}
# Losses {'ner': 0.02582392703961285}
# Losses {'ner': 1.8353994120416843}
# ...

# %% [markdown]
# <font face="微软雅黑" size=3 color=#A52A2A >
#     下面是新的结果<br/>
#     对于已有的默认的entity<br/>
#        虽然money只加了一条训练数据<br/>
#        但是已经学习到了这种模式<br/>
#     对于新加的entity<br/>
#        需要更多的训练数据，和迭代次数

# %%
doc_new=nlp_new(file)
b.displacy.render(doc_new, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">[DU1]</br>Resolution adopted by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the General Assembly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     30 June 2006
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>[on the report of
# ...

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON
